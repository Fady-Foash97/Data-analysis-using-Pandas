# %% [markdown]
# ## Bestseller Books dataset:
# - Bestseller Book Dataset provides the data about bestselling books, author name, reviews, user rating, price, year and genre of so many books.

# %% [markdown]
# ## Columns:
# - Name: name of the book
# - Author: name of the author of the book
# - User Rating: rating given by user to the book
# - Reviews: reviews of the book
# - Price: Price of the given book
# - year: publishing year of the book
# - Genre: genre of the given book

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandasql as psql

# %%
df = pd.read_csv("bestsellers with categories.csv")

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Goal 1: Rank Authors based on their books

# %%
Author = df.groupby('Author')['Name'].count().reset_index()

# %%
Author
# Out:
#                          Author  Name
# 0              Abraham Verghese     2
# 1                Adam Gasiewski     1
# 2                 Adam Mansbach     1
# 3                     Adir Levy     1
# 4    Admiral William H. McRaven     1
# ..                          ...   ...
# 243             Walter Isaacson     3
# 244               William Davis     2
# 245            William P. Young     2
# 246            Wizards RPG Team     3
# 247                Zhi Gang Sha     2
#
# [248 rows x 2 columns]

# %%
Author_sort = Author.sort_values(by = 'Name', ascending = False)

# %%
Top_20_authors = Author_sort.head(20)

# %%
Top_20_authors
# Out:
#                                  Author  Name
# 120                         Jeff Kinney    12
# 92                         Gary Chapman    11
# 226                     Suzanne Collins    11
# 197                        Rick Riordan    11
# 11   American Psychological Association    10
# 90                               Gallup     9
# 73                            Dr. Seuss     9
# 199                         Rob Elliott     8
# 83                           Eric Carle     7
# 27                        Bill O'Reilly     7
# 58                           Dav Pilkey     7
# 220                    Stephen R. Covey     7
# 221                     Stephenie Meyer     7
# 113                        J.K. Rowling     6
# 211                         Sarah Young     6
# 70                      Don Miguel Ruiz     6
# 224                       Stieg Larsson     6
# 230                   The College Board     6
# 76                            E L James     6
# ...

# %%
plt.figure(figsize = (12, 20))
sns.barplot(data = Top_20_authors, y = Top_20_authors['Author'], x = Top_20_authors['Name'])
plt.xlabel('Number of books', size =12)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Author', size = 12)
plt.tight_layout()
plt.title('Top 20 authors')
plt.show()

# %% [markdown]
# ## Conclusions:
# - Top 20 authors with the most books are:
# 1. Jeff Kinney:  diary of a wimpy kid book series (12 books)
# 2. Gary Chapman:  Five Love Languages series (11 books)
# 3. Suzanne Collins:  The Hunger Games book series (11 books)
# 4. Rick Riordan:  Percy Jackson & the Olympians series (11 books)
# 5. American Psychological Association: organization specialized in teaching psychology to Americans	(10 books)
# 6. Gallup: An organization that provides analytics and management consulting to organizations globally (9 books)
# 7. Dr.Seuss:  children books like the cat and the hat, The grinch and the lorax (9 books)
# 8. Rob Elliott:  jokes for kids (8 books)
# 9. Eric Carle:  The Very Hungry Caterpillar and From head to toe. (7 books)
# 10. Bill O'Reilly: A journalist and TV host who wrote many books based on American history (7 books)
# 11. Dav Pilkey:  Cat kid and Dog man (7 books)
# 12. Stephen R. Covey:  The 7 Habits of Highly Effective People (7 books)
# 13.  Stephenie Meyer:  Twilight book series	(7 books)
# 14. J.K. Rowling: Harry Potter series (6 books)
# 15.  Sarah Young: Christian books (6 books)
# 16.  Don Miguel Ruiz: Latin American literature (6 books)
# 17.  Stieg Larsson: The girl with the dragon tatoo (6 books)
# 18.   The College Board: An organization formed to expand access to higher education (6 books)
# 19.   E L James: Fifty shades of grey (6 books)
# 20.   Harper Lee: To kill a mocking bird (6 books)

# %% [markdown]
# ## Goal 2: Fiction vs non fiction

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
Fiction_non_fiction = df.groupby('Genre')['Name'].count().reset_index()

# %%
Fiction_non_fiction
# Out:
#          Genre  Name
# 0      Fiction   240
# 1  Non Fiction   310

# %%
sns.barplot(data = Fiction_non_fiction, x = Fiction_non_fiction['Genre'], y = Fiction_non_fiction['Name'])
plt.xlabel('Fiction and non fiction', size =12)
plt.ylabel('Books', size = 12)
plt.tight_layout()
plt.title('Fiction vs non fiction books')
plt.show()

# %% [markdown]
# ## Conclusions:
# - We noticed that a lot of best sellers are non fiction.
# - This shows that readers are willing to learn more about the real world than to be entertained in a fictional world.

# %% [markdown]
# ## Goal 3: User rating vs reviews

# %%
review = df.groupby('User Rating')['Reviews'].sum().reset_index()

# %%
##review = df[['Reviews', 'User Rating']].sort_values(by = 'Reviews', ascending = False)

# %%
review_sort = review[['User Rating', 'Reviews']].sort_values(by = 'Reviews', ascending = False)

# %%
review_sort
# Out:
#     User Rating  Reviews
# 12          4.8  1757694
# 11          4.7  1475380
# 10          4.6   972304
# 13          4.9   673786
# 9           4.5   553867
# 8           4.4   267481
# 4           4.0   243266
# 7           4.3   209072
# 5           4.1   194305
# 2           3.8    94530
# 3           3.9    73998
# 6           4.2    34268
# 1           3.6    14982
# 0           3.3     9372

# %%
plt.figure(figsize = (10, 12))
sns.barplot(data = review_sort, y = review_sort['Reviews'], x = review_sort['User Rating'], color = 'green')
plt.xlabel('User rating', size =12)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Reviews', size = 12)
plt.tight_layout()
plt.title('User rating vs reviews')
plt.show()

# %% [markdown]
# ## Conclusions:
# - There is a positive relationship between user rating and number of reviews, showing that well-rated books attract more readers.
# - The most reviewed rating is 4.8, this attracts user domination, suggesting popularity.
# - Followed by 4.7, 4.6 user ratings.
# - The lowest reviewd rating is between 3.3 and 3.6, this is due to factors like: poor quality, weak narative, unengaging content, negative word of mouth.

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
plt.figure(figsize=(10,12))
sns.histplot(data=df, x='User Rating', bins=10, kde=True, color='skyblue')
plt.title('Distribution of Book Ratings')
plt.xlabel('User Rating')
plt.ylabel('Number of Books')
plt.show()

# %% [markdown]
# ## Goal 4: Who is the highest rated author?

# %%
query = """SELECT Author, AVG([User Rating]) AS rate FROM df
GROUP BY Author
ORDER BY rate DESC"""

# %%
Author = psql.sqldf(query)

# %%
Author
# Out:
#                    Author  rate
# 0    Sherri Duskey Rinker   4.9
# 1             Sarah Young   4.9
# 2           Rush Limbaugh   4.9
# 3              Pete Souza   4.9
# 4          Patrick Thorpe   4.9
# ..                    ...   ...
# 243          Chris Cleave   4.1
# 244        Muriel Barbery   4.0
# 245         Gillian Flynn   4.0
# 246                Gallup   4.0
# 247           Donna Tartt   3.9
#
# [248 rows x 2 columns]

# %%
Top_21_authors = Author.head(21)
Bottom_20_authors = Author.tail(20)

# %%
Top_21_authors
# Out:
#                    Author      rate
# 0    Sherri Duskey Rinker  4.900000
# 1             Sarah Young  4.900000
# 2           Rush Limbaugh  4.900000
# 3              Pete Souza  4.900000
# 4          Patrick Thorpe  4.900000
# 5          Nathan W. Pyle  4.900000
# 6      Lin-Manuel Miranda  4.900000
# 7              Jill Twiss  4.900000
# 8              Eric Carle  4.900000
# 9   Emily Winfield Martin  4.900000
# 10             Dav Pilkey  4.900000
# 11            Chip Gaines  4.900000
# 12        Bill Martin Jr.  4.900000
# 13         Alice Schertle  4.900000
# 14              Dr. Seuss  4.877778
# 15          Mark R. Levin  4.850000
# 16          J. K. Rowling  4.850000
# 17        Brandon Stanton  4.833333
# 18       Wizards RPG Team  4.800000
# 19       W. Cleon Skousen  4.800000
# 20         Tucker Carlson  4.800000

# %%
Top_20_authors = Top_21_authors.drop([11])

# %%
Top_20_authors
# Out:
#                    Author      rate
# 0    Sherri Duskey Rinker  4.900000
# 1             Sarah Young  4.900000
# 2           Rush Limbaugh  4.900000
# 3              Pete Souza  4.900000
# 4          Patrick Thorpe  4.900000
# 5          Nathan W. Pyle  4.900000
# 6      Lin-Manuel Miranda  4.900000
# 7              Jill Twiss  4.900000
# 8              Eric Carle  4.900000
# 9   Emily Winfield Martin  4.900000
# 10             Dav Pilkey  4.900000
# 12        Bill Martin Jr.  4.900000
# 13         Alice Schertle  4.900000
# 14              Dr. Seuss  4.877778
# 15          Mark R. Levin  4.850000
# 16          J. K. Rowling  4.850000
# 17        Brandon Stanton  4.833333
# 18       Wizards RPG Team  4.800000
# 19       W. Cleon Skousen  4.800000
# 20         Tucker Carlson  4.800000

# %%
Bottom_20_authors
# Out:
#                 Author      rate
# 228     Greg Mortenson  4.300000
# 229       Gayle Forman  4.300000
# 230     Eben Alexander  4.300000
# 231          Amy Ramos  4.300000
# 232          E L James  4.233333
# 233           Rob Bell  4.200000
# 234      Michael Wolff  4.200000
# 235         Mark Twain  4.200000
# 236    Mark Hyman M.D.  4.200000
# 237        Geneen Roth  4.200000
# 238   Elizabeth Strout  4.200000
# 239          Dan Brown  4.200000
# 240       Pierre Dukan  4.100000
# 241      Paula Hawkins  4.100000
# 242  Ian K. Smith M.D.  4.100000
# 243       Chris Cleave  4.100000
# 244     Muriel Barbery  4.000000
# 245      Gillian Flynn  4.000000
# 246             Gallup  4.000000
# 247        Donna Tartt  3.900000

# %%
plt.figure(figsize = (10, 12))
sns.barplot(data = Top_20_authors, y = Top_20_authors['Author'], x = Top_20_authors['rate'], color = 'green')
plt.xlabel('Rating', size =12)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Authors', size = 12)
plt.tight_layout()
plt.title('Top 20 authors by rating')
plt.show()

# %%
plt.figure(figsize = (10, 12))
sns.barplot(data = Bottom_10_authors, y = Bottom_20_authors['Author'], x = Bottom_20_authors['rate'], color = 'green')
plt.xlabel('Rating', size =12)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Authors', size = 12)
plt.tight_layout()
plt.title('Bottom 20 authors by rating')
plt.show()

# %% [markdown]
# ## Conclusions:
# - Multiple authors share the maximum rating of 4.9, popular names like:
# 1. JK Rowling (Harry Potter series)
# 2. Sarah Young (Jesus Calling)
# 3. Pete Souza (American politics)
# 4. Dr.Seuss (The grinch)
# 5. Bill Marting jr. (Animal books)
# - These authors have a common characteristic: they write on interesting topics: Adventure, Politics, Fantasy, Facts.
# - Multiple authors share the minimum rating between the range of 3.9 and 4.3:
# 1. Mark Twain (Tom Sawyer)
# 2. Dan Brown (Da Vinci Code)
# 3. Amy Ramos (Keto diet)
# 4. Gillian Flynn (Gone girl)
# - Reasons could be controversy, misleading information, polarized themes, divided audiences or very old copies.

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Goal 5: Most valuable book.

# %%
Query1 = """SELECT Name, Author, MAX(Price) As [highest price] FROM df
GROUP BY Name, Author
ORDER BY [highest price] DESC"""

# %%
Valuable = psql.sqldf(Query1)

# %%
Valuable
# Out:
#                                                   Name  \
# 0    Diagnostic and Statistical Manual of Mental Di...
# 1                         The Twilight Saga Collection
# 2                             Hamilton: The Revolution
# 3    The Book of Basketball: The NBA According to T...
# 4           Harry Potter Paperback Box Set (Books 1-7)
# ..                                                 ...
# 346                               JOURNEY TO THE ICE P
# 347                                  Little Blue Truck
# 348              The Constitution of the United States
# 349                                        The Getaway
# 350  The Short Second Life of Bree Tanner: An Eclip...
#
#                                Author  highest price
# 0    American Psychiatric Association            105
# 1                     Stephenie Meyer             82
# 2                  Lin-Manuel Miranda             54
# 3                        Bill Simmons             53
# ...

# %%
Valuable_20 = Valuable[['Name','highest price', 'Author']].head(20)

# %%
Valuable_20
# Out:
#                                                  Name  highest price  \
# 0   Diagnostic and Statistical Manual of Mental Di...            105
# 1                        The Twilight Saga Collection             82
# 2                            Hamilton: The Revolution             54
# 3   The Book of Basketball: The NBA According to T...             53
# 4          Harry Potter Paperback Box Set (Books 1-7)             52
# 5   Publication Manual of the American Psychologic...             46
# 6                                            Watchmen             42
# 7                        The Official SAT Study Guide             40
# 8                                       The Alchemist             39
# 9   The Official SAT Study Guide, 2016 Edition (Of...             36
# 10                            A Stolen Life: A Memoir             32
# 11  Fifty Shades Trilogy (Fifty Shades of Grey / F...             32
# 12  A Game of Thrones / A Clash of Kings / A Storm...             30
# ...

# %%
Least_valuable_20 = Valuable[['Name','highest price', 'Author']].tail(20)

# %%
Least_valuable_20
# Out:
#                                                   Name  highest price  \
# 331                       If Animals Kissed Good Night              4
# 332                         Knock-Knock Jokes for Kids              4
# 333                      Laugh-Out-Loud Jokes for Kids              4
# 334  Puppy Birthday to You! (Paw Patrol) (Little Go...              4
# 335                                   The Wonky Donkey              4
# 336  Unicorn Coloring Book: For Kids Ages 4-8 (US E...              4
# 337      A Higher Loyalty: Truth, Lies, and Leadership              3
# 338  A Patriot's History of the United States: From...              2
# 339                     Fear: Trump in the White House              2
# 340  Percy Jackson and the Olympians Paperback Boxe...              2
# 341  The Girl with the Dragon Tattoo (Millennium Se...              2
# 342  Eat This Not That! Supermarket Survival Guide:...              1
# ...

# %%
plt.figure(figsize = (16, 22))
sns.barplot(data = Valuable_20, y = Valuable_20['Name'], x = Valuable_20['highest price'], color = 'green')
plt.xlabel('Price', size =20)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Books', size = 20)
plt.tight_layout()
plt.title('20 Books with the most value')
plt.show()

# %%
plt.figure(figsize = (16, 22))
sns.barplot(data = Least_valuable_20, y = Least_valuable_20['Name'], x = Least_valuable_20['highest price'], color = 'green')
plt.xlabel('Price', size =20)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Books', size = 20)
plt.tight_layout()
plt.title('Least 20 Books by value')
plt.show()

# %% [markdown]
# ## Conclusions:
# - The most valuable books fall into these types:
# 1. Adventure and fiction: Harry Potter, Twilight, Watchmen, The hunger games, Dungeons and dragons, Game of thrones.
# 2. Academic & Reference Manuals: Mental disorders guide, SAT study guide.
# 3. Art: Mastering the Art of French Cooking, Hamilton: The Revolution, Book of Basketball.
# 4. Self help and philosphy: 5 love languages, The Alchemist.
# - The least valuable books fall into:
# 1. Politics: Trump in the white house, A higher loyalty, A patriot's history of the united states.
# 2. Books for kids: jokes for kids book series.
# 3. Instructions: Constitution of the United States, Eat this not that.
# 4. Polarizing books: Girl with the dragon tatoo.

# %% [markdown]
# ## Summary:
# - Readers prefer books that:
# 1. take them to other worlds and universes like Harry Potter, Hunger games, Dungeons and dragons.
# 2. help them in their studies and professions like Mental disorders guide, Mental disorders guide.
# 3. Works that are visually rich, cleverly structured, or culturally significant like Art of French Cooking, Hamilton: The Revolution, Book of Basketball.
# 4. help and teach them about life like: 5 love languages, The Alchemist.
# - They don't prefer books that:
# 1. divide them be it
# - political ones like: Trump in the white house, A higher loyalty, A patriot's history of the united states.
# - controversal like: Girl with the dragon tatoo.
# 2. offer quick reads without any benefit: jokes for kids book series.
# 3. Instructions: Constitution of the United States, Eat this not that.

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Goal 6: User rating vs Price (Do high prices mean high user rating?)

# %%
User_rating_vs_Price = df.groupby('User Rating')['Price'].mean().round().reset_index()

# %%
User_rating_vs_Price
# Out:
#     User Rating  Price
# 0           3.3   12.0
# 1           3.6   19.0
# 2           3.8   14.0
# 3           3.9   18.0
# 4           4.0   15.0
# 5           4.1   12.0
# 6           4.2   12.0
# 7           4.3   13.0
# 8           4.4   14.0
# 9           4.5   21.0
# 10          4.6   12.0
# 11          4.7   13.0
# 12          4.8   11.0
# 13          4.9   10.0

# %%
User_rating_vs_Price_sort = User_rating_vs_Price.sort_values(by = 'Price', ascending = False)

# %%
User_rating_vs_Price_sort
# Out:
#     User Rating  Price
# 9           4.5   21.0
# 1           3.6   19.0
# 3           3.9   18.0
# 4           4.0   15.0
# 2           3.8   14.0
# 8           4.4   14.0
# 7           4.3   13.0
# 11          4.7   13.0
# 0           3.3   12.0
# 5           4.1   12.0
# 6           4.2   12.0
# 10          4.6   12.0
# 12          4.8   11.0
# 13          4.9   10.0

# %%
plt.figure(figsize = (10, 12))
sns.barplot(data = User_rating_vs_Price_sort, y = User_rating_vs_Price_sort['Price'], 
            x = User_rating_vs_Price_sort['User Rating'], color = 'orange')
plt.xlabel('User rating', size = 17)
##plt.xticks(rotation = 45, ha = 'right')
plt.ylabel('Price', size = 17)
plt.tight_layout()
plt.title('Price vs user rating')
plt.show()

# %% [markdown]
# # Conclusions:
# - There is a non-linear relationship between user rating and price, high prices do not gurantee high user rating and vice versa.
# - Some of the highest rated books have moderate prices, which shows that Readers value content over cost.
# - Some expensive books such as Academic studies and box sets have good ratings, likely due to their format or collector appeal especially on box sets.
# - Lower rated books are expensive, these books could be either polarizing books or disposable quick reads.
# - Overall: what drives reader satisfaction is not the value or cost of the book but the content underneath, its relevance and timelessness.
