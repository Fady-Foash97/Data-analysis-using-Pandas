# %% [markdown]
# ## Dataset information:

# %% [markdown]
# - Brand: The manufacturer of the laptop (e.g., Dell, HP, Apple, Asus, Lenovo).
# - Processor: The CPU model, including Intel (i3, i5, i7, i9) and AMD Ryzen (3, 5, 7, 9).
# - RAM (GB): The laptop's memory size (e.g., 4GB, 8GB, 16GB, 32GB, 64GB).
# - Storage: Type and size of storage (e.g., 256GB SSD, 512GB SSD, 1TB HDD).
# - GPU: The graphics processing unit, either integrated or dedicated (e.g., Nvidia GTX 1650, RTX 3060).
# - Screen Size (inch): The display size in inches (e.g., 13.3", 14", 15.6", 17.3").
# - Resolution: The screen resolution, such as 1366x768, 1920x1080, 2560x1440, or 3840x2160.
# - Battery Life (hours): Estimated battery life in hours, ranging from 4 to 12 hours.
# - Weight (kg): The weight of the laptop in kilograms, between 1.2kg and 3.5kg.
# - Operating System: The pre-installed OS, including Windows, macOS, Linux, and FreeDOS.
# - Price ($): The target variable, representing the laptop's price in US dollars.

# %% [markdown]
# # Data to be analyzed:

# %% [markdown]
# - What brand have the best market in laptops?
# - What specifcations that affect laptop prices?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("laptop_prices.csv")

# %%
df
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
df = df.rename(columns={"Price ($)": "Price"})

# %%
df
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %% [markdown]
# - What brand have the best market in laptops?

# %%
df1 = df.sort_values(by="Price", ascending= False)

# %%
df1
# Out:
#            Brand    Processor  RAM (GB)    Storage                 GPU  \
# 3790       Apple  AMD Ryzen 9        64  512GB SSD  AMD Radeon RX 6600
# 10436      Apple  AMD Ryzen 9        64  256GB SSD     Nvidia RTX 3080
# 11580      Apple  AMD Ryzen 9        64    1TB SSD  AMD Radeon RX 6800
# 7609       Apple     Intel i9        64  512GB SSD  AMD Radeon RX 6800
# 5960       Apple  AMD Ryzen 9        64    2TB SSD     Nvidia RTX 3060
# ...          ...          ...       ...        ...                 ...
# 10375       Asus  AMD Ryzen 5         4    1TB HDD          Integrated
# 2689        Acer     Intel i5         4    1TB HDD          Integrated
# 10468       Dell     Intel i3         4    1TB HDD          Integrated
# 8207        Asus  AMD Ryzen 3         4    2TB SSD          Integrated
# 11587  Microsoft     Intel i3         4    1TB HDD          Integrated
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
df1.head(10)
# Out:
#        Brand    Processor  RAM (GB)    Storage                 GPU  \
# 3790   Apple  AMD Ryzen 9        64  512GB SSD  AMD Radeon RX 6600
# 10436  Apple  AMD Ryzen 9        64  256GB SSD     Nvidia RTX 3080
# 11580  Apple  AMD Ryzen 9        64    1TB SSD  AMD Radeon RX 6800
# 7609   Apple     Intel i9        64  512GB SSD  AMD Radeon RX 6800
# 5960   Apple  AMD Ryzen 9        64    2TB SSD     Nvidia RTX 3060
# 6440   Apple     Intel i9        64  512GB SSD     Nvidia RTX 2060
# 11514  Apple  AMD Ryzen 9        64  256GB SSD  AMD Radeon RX 6600
# 6441   Razer  AMD Ryzen 9        64    2TB SSD  AMD Radeon RX 6800
# 10622  Apple  AMD Ryzen 9        64    2TB SSD  AMD Radeon RX 6800
# 8915   Apple  AMD Ryzen 9        64    1TB SSD  AMD Radeon RX 6800
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# 3790                 15.6  3840x2160                   7.5         1.37
# 10436                15.6  3840x2160                   5.4         1.65
# ...

# %%
df2 = df1.groupby("Brand")["Price"].sum().reset_index()

# %%
df2
# Out:
#        Brand       Price
# 0       Acer  2229936.42
# 1      Apple  3679189.72
# 2       Asus  2245322.14
# 3       Dell  2307556.16
# 4         HP  2341730.63
# 5     Lenovo  2265343.33
# 6        MSI  2995887.15
# 7  Microsoft  2320864.17
# 8      Razer  3032115.53
# 9    Samsung  2278325.43

# %%
df3 = df2.sort_values(by="Price", ascending= False)

# %%
df3
# Out:
#        Brand       Price
# 1      Apple  3679189.72
# 8      Razer  3032115.53
# 6        MSI  2995887.15
# 4         HP  2341730.63
# 7  Microsoft  2320864.17
# 3       Dell  2307556.16
# 9    Samsung  2278325.43
# 5     Lenovo  2265343.33
# 2       Asus  2245322.14
# 0       Acer  2229936.42

# %%
plt.figure(figsize=(10,10))
plt.pie(df3["Price"] ,labels=df3["Brand"] , autopct='%1.1f%%')
plt.title("Brand market")
plt.show()

# %%
fig = px.pie(df3, values=df3["Price"], names=df3["Brand"])
fig.update_layout(width= 1000, height = 800, title="Brand market")
fig.show()

# %% [markdown]
# ## Conclusions:

# %% [markdown]
# - Apple holds the highest market share in laptops at 14%.
# - Razer and MSI follow apple, they have a market share of 11%
# - Hp and Microsoft have a market share of 9%
# - Dell, Samsung, Lenovo, Asus and Acer have a market share of 8%

# %% [markdown]
# ## Why Apple leads in laptops:

# %% [markdown]
# - Two words: Marketing and product diversity!
# - Apple focuses on innovation and premium quality.
# - Apple has a diversity of products, from iPhones to iPads and iPods to laptops and macbooks!

# %% [markdown]
# ## What specifcations that affect laptop prices??

# %%
df
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
df4 = df.sort_values(by="Price", ascending=False)

# %%
df4
# Out:
#            Brand    Processor  RAM (GB)    Storage                 GPU  \
# 3790       Apple  AMD Ryzen 9        64  512GB SSD  AMD Radeon RX 6600
# 10436      Apple  AMD Ryzen 9        64  256GB SSD     Nvidia RTX 3080
# 11580      Apple  AMD Ryzen 9        64    1TB SSD  AMD Radeon RX 6800
# 7609       Apple     Intel i9        64  512GB SSD  AMD Radeon RX 6800
# 5960       Apple  AMD Ryzen 9        64    2TB SSD     Nvidia RTX 3060
# ...          ...          ...       ...        ...                 ...
# 10375       Asus  AMD Ryzen 5         4    1TB HDD          Integrated
# 2689        Acer     Intel i5         4    1TB HDD          Integrated
# 10468       Dell     Intel i3         4    1TB HDD          Integrated
# 8207        Asus  AMD Ryzen 3         4    2TB SSD          Integrated
# 11587  Microsoft     Intel i3         4    1TB HDD          Integrated
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
df5 = df4.groupby("Processor")["Price"].sum().reset_index()

# %%
df5
# Out:
#      Processor       Price
# 0  AMD Ryzen 3  2302379.35
# 1  AMD Ryzen 5  2647789.49
# 2  AMD Ryzen 7  3211661.93
# 3  AMD Ryzen 9  4515046.10
# 4     Intel i3  2442406.63
# 5     Intel i5  2613821.03
# 6     Intel i7  3472116.92
# 7     Intel i9  4491049.23

# %%
df6 = df5.sort_values(by="Price", ascending = False)

# %%
df6
# Out:
#      Processor       Price
# 3  AMD Ryzen 9  4515046.10
# 7     Intel i9  4491049.23
# 6     Intel i7  3472116.92
# 2  AMD Ryzen 7  3211661.93
# 1  AMD Ryzen 5  2647789.49
# 5     Intel i5  2613821.03
# 4     Intel i3  2442406.63
# 0  AMD Ryzen 3  2302379.35

# %%
df7 = df4.groupby("RAM (GB)")["Price"].sum().reset_index()

# %%
df7
# Out:
#    RAM (GB)       Price
# 0         4  3276372.61
# 1         8  3562753.64
# 2        16  4380440.60
# 3        32  5992857.87
# 4        64  8483845.96

# %%
df8 = df7.sort_values(by="Price", ascending= False)

# %%
df8
# Out:
#    RAM (GB)       Price
# 4        64  8483845.96
# 3        32  5992857.87
# 2        16  4380440.60
# 1         8  3562753.64
# 0         4  3276372.61

# %%
df9 = df4.groupby("Storage")["Price"].sum().reset_index()

# %%
df9
# Out:
#      Storage       Price
# 0    1TB HDD  4395372.53
# 1    1TB SSD  5296219.14
# 2  256GB SSD  5268586.58
# 3    2TB SSD  5334836.78
# 4  512GB SSD  5401255.65

# %%
df10 = df9.sort_values(by="Price", ascending= False)

# %%
df10
# Out:
#      Storage       Price
# 4  512GB SSD  5401255.65
# 3    2TB SSD  5334836.78
# 1    1TB SSD  5296219.14
# 2  256GB SSD  5268586.58
# 0    1TB HDD  4395372.53

# %%
df11 = df4.groupby("GPU")["Price"].sum().reset_index()

# %%
df11
# Out:
#                   GPU       Price
# 0  AMD Radeon RX 6600  3839530.08
# 1  AMD Radeon RX 6800  3871653.58
# 2          Integrated  2480962.48
# 3     Nvidia GTX 1650  3889909.90
# 4     Nvidia RTX 2060  3968696.12
# 5     Nvidia RTX 3060  3923927.10
# 6     Nvidia RTX 3080  3721591.42

# %%
df12 = df11.sort_values(by="Price", ascending= False)

# %%
df12
# Out:
#                   GPU       Price
# 4     Nvidia RTX 2060  3968696.12
# 5     Nvidia RTX 3060  3923927.10
# 3     Nvidia GTX 1650  3889909.90
# 1  AMD Radeon RX 6800  3871653.58
# 0  AMD Radeon RX 6600  3839530.08
# 6     Nvidia RTX 3080  3721591.42
# 2          Integrated  2480962.48

# %%
df13 = df4.groupby("Resolution")["Price"].sum().reset_index()

# %%
df13
# Out:
#   Resolution       Price
# 0   1366x768  4488303.41
# 1  1920x1080  5504468.58
# 2  2560x1440  6720633.29
# 3  3840x2160  8982865.40

# %%
df14 = df13.sort_values(by="Price", ascending= False)

# %%
df14
# Out:
#   Resolution       Price
# 3  3840x2160  8982865.40
# 2  2560x1440  6720633.29
# 1  1920x1080  5504468.58
# 0   1366x768  4488303.41

# %%
df15 = df4.groupby("Operating System")["Price"].sum().reset_index()

# %%
df15
# Out:
#   Operating System       Price
# 0          FreeDOS  6464731.81
# 1            Linux  6418575.80
# 2          Windows  6442717.58
# 3            macOS  6370245.49

# %%
df16 = df15.sort_values(by = "Price", ascending = False)

# %%
df16
# Out:
#   Operating System       Price
# 0          FreeDOS  6464731.81
# 2          Windows  6442717.58
# 1            Linux  6418575.80
# 3            macOS  6370245.49

# %%
fig = px.bar(df6, x=df6["Processor"], y=df6["Price"], color="Processor")
fig.update_layout(xaxis_title="Processor", yaxis_title="Price", title="Processor vs Price", width=1000, height= 600)
fig.show()

# %%
fig = px.line(df8, x=df8["RAM (GB)"], y=df8["Price"], markers= True)
fig.update_layout(xaxis_title="RAM", yaxis_title="Price", title="RAM vs Price", width= 1000, height=900)
fig.show()

# %%
fig = px.bar(df10, df10["Storage"], df10["Price"], color="Storage", text_auto= True)
fig.update_layout(title="Storage vs Price", width= 700, height=900)
fig.show()

# %%
fig = px.bar(df12, x=df12["GPU"], y=df12["Price"], color="GPU", text_auto = True)
fig.update_layout(xaxis_title = "GPU", yaxis_title = "Price", title="GPU vs Price", width=1000, height= 600)
fig.show()

# %%
fig = px.bar(df14, x=df14["Resolution"], y=df14["Price"], color="Resolution", text_auto = True )
fig.update_layout(xaxis_title = "Resolution", yaxis_title = "Price", title="Resolution vs Price", width=1000, height= 600)
fig.show()

# %%
fig = px.bar(df16, x=df16["Operating System"], y=df14["Price"], color="Operating System", text_auto = True )
fig.update_layout(xaxis_title = "Operating System", yaxis_title = "Price", title="Operating System vs Price", width=1000, height= 600)
fig.show()

# %% [markdown]
# ## From the bars above, we have noticed that:

# %% [markdown]
# - Processors, RAM (Random Access Memory), , Storage units, GPUs (Graphical Processing Unit), Screen resolution, Operating systems are the factors that affect the prices of laptops.

# %% [markdown]
# ## For RAM:

# %% [markdown]
# - As the RAM memory increases, the price of the laptop increases.

# %% [markdown]
# ## For storage units:

# %% [markdown]
# - The highest storage unit (2 TB SSD) has the highest price, but cheaper than the 512 GB SSD storage unit which has less storage.

# %% [markdown]
# ## For GPUs:

# %% [markdown]
# - Nividia has the highest prices in GPUS (Nividia RTX 2060, Nividia RTX 3060, Nividia GTX 1650, Nividia RTX 3080 but a bit cheaper), while AMD has cheaper prices than Nividia (AMD Radeon RX 6800, AMD Radeon RX 6600) both of them are higher than Nividia RTX 3080 but cheaper than   Nividia RTX 2060, Nividia RTX 3060 and Nividia GTX 1650.

# %% [markdown]
# - This shows that Nividia has the biggest market share in GPUs, due to its brand, performance advantages in both gaming, graphical processing and professional computing.

# %% [markdown]
# ## For Resolution:

# %% [markdown]
# - The bigger the resolution, the higher the price of the laptop.

# %% [markdown]
# ## For Operaing system:

# %% [markdown]
# - FreeDOS is the most expensive operating system followed by Windows.
