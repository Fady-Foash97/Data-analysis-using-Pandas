# %%
import matplotlib.pyplot as plt

# %%
subjects = ["English", "Maths", "Chemistry", "Physics", "History", "Tech", "Music"]
marks = [6, 8, 7, 5, 2, 7, 3]
colors = ["blue", "green", "brown", "purple", "gold", "blue", "orange"]
plt.bar(subjects, marks, color= colors)
plt.xlabel("Subjects",  loc= "left", fontdict = {"fontweight": "bold", "fontname": "arial", "fontsize": 14})
plt.ylabel("Mark of students")
plt.title("Students in 3rd grade")
plt.show()
subjects = ["English", "Maths", "Chemistry", "Physics", "History", "Tech", "Music"]
marks = [6, 8, 2, 5, 7, 8, 6]
colors = ["blue", "green", "brown", "purple", "gold", "blue", "orange"]
plt.bar(subjects, marks, color= colors)
plt.xlabel("Subjects", loc= "left", fontdict = {"fontweight": "bold", "fontname": "arial", "fontsize": 14})
plt.ylabel("Mark of students")
plt.title("Students in 4rth grade")
plt.show()

# %% [markdown]
# # Conclusions from data:

# %% [markdown]
# # Students in 3rd grade and 4rth grade are very good in both technology and Maths

# %% [markdown]
# # Students in 3rd grade are very good in chemistry while students in 4rth grade are not so good in this subject

# %% [markdown]
# # Students in 4rth grade are very good in history while those in 3rd grade are not as good in history

# %% [markdown]
# # Decisions for 3rd grade:

# %% [markdown]
# # The school should make trips to historical landmarks and museums to make history interesting for students

# %% [markdown]
# # We should bring some well known music composers to teach our students how to play music, music would be so much fun!

# %% [markdown]
# # Decisions for 4rth grade:

# %% [markdown]
# # The school should make practical exercises for our students, to show the effect of combining two elements together, even make competitions
