# %% [markdown]
# ## Pixar movies dataset:

# %% [markdown]
# - This dataset contains financial, critical, and audience reception data for Pixar movies. It includes 28 entries, each representing a different Pixar film, along with multiple attributes detailing their performance and reception.

# %% [markdown]
# ## dataset columns:

# %% [markdown]
# - ID – A unique identifier for each film.
# - Film – The title of the Pixar movie.
# - Film Rating – The movie’s MPAA rating (e.g., G, PG).
# - Cinema Score – The audience score from CinemaScore, representing general public reception (e.g., A+, A, A-).
# - Release Date – The date when the movie was released in theaters.
# - Budget – The estimated production cost of the film in dollars.
# - Box Office US & Canada – Total revenue generated from ticket sales in the United States and Canada.
# - Box Office Other – Total revenue from international markets (outside the US & Canada).
# - Box Office Worldwide – The sum of US & Canada and international box office earnings.
# - Rotten Tomatoes Score – The critic approval rating (percentage) from Rotten Tomatoes.
# - IMDb Score – The average audience rating of the film on IMDb (on a scale of 1 to 10).

# %% [markdown]
# ## Goals:
# 1. Financial Performance Analysis 💰
# - Identify the highest-grossing Pixar film worldwide.
# - Compare domestic (US/Canada) vs. international revenue.
# - Find the ROI (Return on Investment) for each film: ROI= Box Office Worldwide - Budget / Budget * 100
# - Check if higher budgets lead to higher revenue using correlation analysis.
# 2. Audience Reception & Ratings ⭐
# - Identify which films have the highest Rotten Tomatoes and IMDb scores.
# - Compare critical reception vs. box office performance.
# 3. Release Date Trends 📅
# - Analyze which years or decades had the most successful releases.
# - Find the most profitable release month for Pixar movies.
# 4. Franchise Success 🎬
# - Compare Toy Story films vs. other Pixar franchises.
# - Analyze if sequels tend to perform better or worse than original movies.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("pixar_films.csv")

# %%
df
# Out:
#     ID                 film release_date     budget  box_office_us_canada  \
# 0    1            Toy Story    22-Nov-95   30000000             223225679
# 1    2         A Bug's Life    25-Nov-98  120000000             162798565
# 2    3          Toy Story 2    24-Nov-99   90000000             245852179
# 3    4       Monsters, Inc.     2-Nov-01  115000000             255873250
# 4    5         Finding Nemo    30-May-03   94000000             339714978
# 5    6      The Incredibles     5-Nov-04   92000000             261441092
# 6    7                 Cars     9-Jun-06  120000000             244082982
# 7    8          Ratatouille    29-Jun-07  150000000             206445654
# 8    9               WALL-E    27-Jun-08  180000000             223808164
# 9   10                   Up    29-May-09  175000000             293004164
# 10  11          Toy Story 3    18-Jun-10  200000000             415004880
# 11  12               Cars 2    24-Jun-11  200000000             191452396
# ...

# %% [markdown]
# ## Goal 1: Financial Performance Analysis:
# ## Q1: What is the movie with the highest box office record?

# %%
df[["box_office_worldwide","box_office_us_canada", "box_office_other","film"]].sort_values(by = "box_office_worldwide", ascending= False)
# Out:
#     box_office_worldwide  box_office_us_canada  box_office_other  \
# 27            1698030965             652980194        1045050771
# 19            1242805359             608581744         634223615
# 20            1073394593             434038008         639356585
# 10            1066969703             415004880         651964823
# 16            1028570889             486295561         542275328
# 4              871014978             339714978         531300000
# 14             857611174             356461711         501149463
# 18             814641172             210460015         604181157
# 13             743559607             268492764         475066843
# 9              735099082             293004164         442094918
# 5              631442092             261441092         370001000
# 7              623726085             206445654         417280431
# 11             559852396             191452396         368400000
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["box_office_worldwide"], width= 1200, height = 900)
fig.update_layout(xaxis_title = "Film", yaxis_title = "Box office worldwide", title = "Box office worldwide for films")
fig.show()
# Out:
# <div>                            <div id="da056bbd-db22-40a8-ae90-58cf10c51439" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da056bbd-db22-40a8-ae90-58cf10c51439")) {                    Plotly.newPlot(                        "da056bbd-db22-40a8-ae90-58cf10c51439",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003ebox_office_worldwide=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","A Bug's Life","Toy Story 2","Monsters, Inc.","Finding Nemo","The Incredibles","Cars","Ratatouille","WALL-E","Up","Toy Story 3","Cars 2","Brave","Monsters Univer
# ...

# %%
df[["box_office_worldwide","box_office_us_canada", "box_office_other","film", "release_date"]].sort_values(by = "box_office_us_canada", ascending= False)
# Out:
#     box_office_worldwide  box_office_us_canada  box_office_other  \
# 27            1698030965             652980194        1045050771
# 19            1242805359             608581744         634223615
# 16            1028570889             486295561         542275328
# 20            1073394593             434038008         639356585
# 10            1066969703             415004880         651964823
# 14             857611174             356461711         501149463
# 4              871014978             339714978         531300000
# 9              735099082             293004164         442094918
# 13             743559607             268492764         475066843
# 5              631442092             261441092         370001000
# 3              528773250             255873250         272900000
# 2              511358276             245852179         265506097
# 6              461983149             244082982         217900167
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["box_office_us_canada"], width= 1200, height = 900)
fig.update_layout(xaxis_title = "Film", yaxis_title = "box office in US and Canada", title = "Domestic box office for films")
fig.show()
# Out:
# <div>                            <div id="44fb725b-f534-4c43-ba9b-ce118102af00" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44fb725b-f534-4c43-ba9b-ce118102af00")) {                    Plotly.newPlot(                        "44fb725b-f534-4c43-ba9b-ce118102af00",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003ebox_office_us_canada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","A Bug's Life","Toy Story 2","Monsters, Inc.","Finding Nemo","The Incredibles","Cars","Ratatouille","WALL-E","Up","Toy Story 3","Cars 2","Brave","Monsters Univer
# ...

# %%
df[["box_office_worldwide","box_office_us_canada", "box_office_other","film", "release_date"]].sort_values(by = "box_office_other", ascending= False)
# Out:
#     box_office_worldwide  box_office_us_canada  box_office_other  \
# 27            1698030965             652980194        1045050771
# 10            1066969703             415004880         651964823
# 20            1073394593             434038008         639356585
# 19            1242805359             608581744         634223615
# 18             814641172             210460015         604181157
# 16            1028570889             486295561         542275328
# 4              871014978             339714978         531300000
# 14             857611174             356461711         501149463
# 13             743559607             268492764         475066843
# 9              735099082             293004164         442094918
# 7              623726085             206445654         417280431
# 5              631442092             261441092         370001000
# 11             559852396             191452396         368400000
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["box_office_other"], width= 1200, height = 900)
fig.update_layout(xaxis_title = "Film", yaxis_title = "box office in international markets", title = "International box office for films")
fig.show()
# Out:
# <div>                            <div id="77ccd4f8-7c41-4a12-a85c-d28a8107dde8" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77ccd4f8-7c41-4a12-a85c-d28a8107dde8")) {                    Plotly.newPlot(                        "77ccd4f8-7c41-4a12-a85c-d28a8107dde8",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003ebox_office_other=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","A Bug's Life","Toy Story 2","Monsters, Inc.","Finding Nemo","The Incredibles","Cars","Ratatouille","WALL-E","Up","Toy Story 3","Cars 2","Brave","Monsters University
# ...

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# - Inside out 2 , the latest movie from Pixar in 2024 has the biggest box office number world wide.
# - It has both the biggest box office number in both domestic market (US and Canada) and international market (Other countries).
# - The box office number in the international market for Inside out 2 is bigger than the domestic market (US and Canada).

# %% [markdown]
# ## Q2: Compare the box office performace between domestic market (US and Canada) and international market (other countries)

# %%
fig = px.scatter(df, x = df["box_office_worldwide"], y = df["box_office_us_canada"], width= 1200, height = 900)
fig.update_layout(xaxis = dict(title = "Box office worldwide", showgrid = True),
                  yaxis = dict(title = "Box office in domestic market", showgrid = True), 
                  title = "Box office worldwide vs domestic")
fig.show()
# Out:
# <div>                            <div id="0d583522-467a-45a7-98cc-d1ca67fda80f" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d583522-467a-45a7-98cc-d1ca67fda80f")) {                    Plotly.newPlot(                        "0d583522-467a-45a7-98cc-d1ca67fda80f",                        [{"hovertemplate":"box_office_worldwide=%{x}\u003cbr\u003ebox_office_us_canada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[394436586,363258859,511358276,528773250,871014978,631442092,461983149,623726085,521311860,735099082,1066969703,559852396,538983207,743559607,857611174,332207671,1028570889,383930656,814641172,1242805359,10733
# ...

# %%
fig = px.scatter(df, x = df["box_office_worldwide"], y = df["box_office_other"], width= 1200, height = 900)
fig.update_layout(xaxis = dict(title = "Box office worldwide", showgrid = True)
                , yaxis= dict(title = "Box office in international market", showgrid = True),
                  title = "Box office worldwide vs international")
fig.show()
# Out:
# <div>                            <div id="028cd08e-b8e7-4a9c-9b15-f0597ab35997" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("028cd08e-b8e7-4a9c-9b15-f0597ab35997")) {                    Plotly.newPlot(                        "028cd08e-b8e7-4a9c-9b15-f0597ab35997",                        [{"hovertemplate":"box_office_worldwide=%{x}\u003cbr\u003ebox_office_other=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[394436586,363258859,511358276,528773250,871014978,631442092,461983149,623726085,521311860,735099082,1066969703,559852396,538983207,743559607,857611174,332207671,1028570889,383930656,814641172,1242805359,107339459
# ...

# %%
fig = px.scatter(df, x = df["box_office_other"], y = df["box_office_us_canada"], width= 1200, height = 900)
fig.update_layout(xaxis = dict(title = "Box office in international market", showgrid= True)
                  , yaxis= dict(title = "Box office in domestic market", showgrid = True),
                     title = "Box office international vs domestic")
fig.show()
# Out:
# <div>                            <div id="347e68f0-ea71-4d44-9ec8-bfe06768bd81" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("347e68f0-ea71-4d44-9ec8-bfe06768bd81")) {                    Plotly.newPlot(                        "347e68f0-ea71-4d44-9ec8-bfe06768bd81",                        [{"hovertemplate":"box_office_other=%{x}\u003cbr\u003ebox_office_us_canada=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[171210907,200460294,265506097,272900000,531300000,370001000,217900167,417280431,297503696,442094918,651964823,368400000,301700000,475066843,501149463,209120551,542275328,231029541,604181157,634223615,639356585,80
# ...

# %% [markdown]
# ## Conclusion:
# -  Movies generate the highest revenue in international markets especially for markets with large populations like China and India.

# %% [markdown]
# ## Q3: Find the ROI (Return on Investment) for each film: ROI= Box Office Worldwide - Budget / Budget * 100

# %%
df.head()
# Out:
#    ID            film release_date     budget  box_office_us_canada  \
# 0   1       Toy Story    22-Nov-95   30000000             223225679
# 1   2    A Bug's Life    25-Nov-98  120000000             162798565
# 2   3     Toy Story 2    24-Nov-99   90000000             245852179
# 3   4  Monsters, Inc.     2-Nov-01  115000000             255873250
# 4   5    Finding Nemo    30-May-03   94000000             339714978
#
#    box_office_other  box_office_worldwide  rotten_tomatoes_score  imdb_score
# 0         171210907             394436586                    100         8.3
# 1         200460294             363258859                     92         7.2
# 2         265506097             511358276                    100         7.9
# 3         272900000             528773250                     96         8.1
# 4         531300000             871014978                     99         8.2

# %%
df["ROI (Return on Investment)"] = df["box_office_worldwide"] - df["budget"] / df["budget"] * 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 2.3+ KB

# %%
df_sorted = df[["ROI (Return on Investment)", "film"]].sort_values(by = "ROI (Return on Investment)", ascending = False)

# %%
fig = px.bar(df, x = df_sorted["film"], y = df_sorted["ROI (Return on Investment)"], width= 1200, height = 900)
fig.update_layout(xaxis_title= "Film", yaxis_title = "Return on investment", title = "Return on investment for film")
fig.show()
# Out:
# <div>                            <div id="3ca49fa5-0cc6-48f2-a50d-09f8481a2417" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ca49fa5-0cc6-48f2-a50d-09f8481a2417")) {                    Plotly.newPlot(                        "3ca49fa5-0cc6-48f2-a50d-09f8481a2417",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Inside Out 2","Incredibles 2","Toy Story 4","Toy Story 3","Finding Dory","Finding Nemo","Inside Out","Coco","Monsters University","Up","The Incredibles","Ratatouille","Cars 2","Brave","Monsters,
# ...

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# - Inside out 2 has the highest return on investment, that means it's the most profitable movie in Pixar's catalogue.
# - Reasons are Strong audience reception and controlled production costs.
# - Several other films have strong ROI: Incredibles 2, Toy story 4, Finding Dory, Inside out, Toy story 3, Finding Nemo.
# - These films benefited from strong brand recongition (Toy story, Incredibles and Finding Nemo)
# - Films with the lowest ROI are: Onward, Soul, Luca, Turning red, Lightyear, Elemental
# - Reasons are:
# - Luca, Turning red and Soul got Disney plus releases before theaters.
# - Onward was released in March 2020 before worldwide pandemic shut down.
# - Lightyear had low audience reception due to unethical marketing techniques, generic plot, no emotional core and poor pacing.

# %% [markdown]
# ## Q4: Budget vs Revenue: Do high budgets mean high revenues?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 2.3+ KB

# %%
df[["film", "budget", "box_office_worldwide"]].sort_values(by = "budget", ascending= False)
# Out:
#                    film     budget  box_office_worldwide
# 27         Inside Out 2  200000000            1698030965
# 16         Finding Dory  200000000            1028570889
# 26            Elemental  200000000             496444308
# 25            Lightyear  200000000             226425420
# 20          Toy Story 4  200000000            1073394593
# 19        Incredibles 2  200000000            1242805359
# 10          Toy Story 3  200000000            1066969703
# 11               Cars 2  200000000             559852396
# 13  Monsters University  200000000             743559607
# 12                Brave  185000000             538983207
# 8                WALL-E  180000000             521311860
# 24          Turning Red  175000000              21813358
# 21               Onward  175000000             141940042
# 18                 Coco  175000000             814641172
# 17               Cars 3  175000000             383930656
# ...

# %%
df[["film", "budget", "box_office_worldwide"]].sort_values(by = "box_office_worldwide", ascending= False)
# Out:
#                    film     budget  box_office_worldwide
# 27         Inside Out 2  200000000            1698030965
# 19        Incredibles 2  200000000            1242805359
# 20          Toy Story 4  200000000            1073394593
# 10          Toy Story 3  200000000            1066969703
# 16         Finding Dory  200000000            1028570889
# 4          Finding Nemo   94000000             871014978
# 14           Inside Out  175000000             857611174
# 18                 Coco  175000000             814641172
# 13  Monsters University  200000000             743559607
# 9                    Up  175000000             735099082
# 5       The Incredibles   92000000             631442092
# 7           Ratatouille  150000000             623726085
# 11               Cars 2  200000000             559852396
# 12                Brave  185000000             538983207
# 3        Monsters, Inc.  115000000             528773250
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["budget"], width= 1200, height = 900)
fig.update_layout(xaxis_title = "film", yaxis_title = "Budget", title = "Budget for films")
fig.show()
# Out:
# <div>                            <div id="7aafb09a-4c9f-40c4-8e89-fd9e15717067" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aafb09a-4c9f-40c4-8e89-fd9e15717067")) {                    Plotly.newPlot(                        "7aafb09a-4c9f-40c4-8e89-fd9e15717067",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003ebudget=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","A Bug's Life","Toy Story 2","Monsters, Inc.","Finding Nemo","The Incredibles","Cars","Ratatouille","WALL-E","Up","Toy Story 3","Cars 2","Brave","Monsters University","Inside 
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["box_office_worldwide"], width= 1200, height = 900)
fig.update_layout(xaxis_title = "film", yaxis_title = "box_office_worldwide", title = "Box office worldwide for films")
fig.show()
# Out:
# <div>                            <div id="8b41d7a2-8937-40e2-8e0f-c55966add51f" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b41d7a2-8937-40e2-8e0f-c55966add51f")) {                    Plotly.newPlot(                        "8b41d7a2-8937-40e2-8e0f-c55966add51f",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003ebox_office_worldwide=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","A Bug's Life","Toy Story 2","Monsters, Inc.","Finding Nemo","The Incredibles","Cars","Ratatouille","WALL-E","Up","Toy Story 3","Cars 2","Brave","Monsters Univer
# ...

# %% [markdown]
# ## Conclusions:
# - Inside out 2 has the highest budget by 200 million dollars and gained the highest revenue by 1.698031 billion dollars
# - A lot of pixar movies have the highest budgets but vary in revenues gained
# ## for example:
# - Cars 2 has the highest budget by 200 million dollars but the lowest revenue by 559.825 million dollars.
# - Incredibles 2 has the highest budget by 200 million dollars  and 1.242805 billion dollars.
# - Lightyear which was released 2 years ago before Inside out 2, has the highest budget by 200 million dollars but the lowest revenue by 228. 425 million dollars.
# ## In short:
# - highest budgets sometimes means highest revenues but that's not the case, as we have seen from the data collected and analyzed.
# - what makes a movie watchable isn't the biggest budgets, it's its timeless themes, emoional core, how everyone relate to it.

# %% [markdown]
# ## Goal 2: Audience Reception & Ratings

# %% [markdown]
# ## Q1: Identify which films have the highest Rotten Tomatoes and IMDb scores.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 2.3+ KB

# %%
df[["rotten_tomatoes_score", "imdb_score"]]
# Out:
#     rotten_tomatoes_score  imdb_score
# 0                     100         8.3
# 1                      92         7.2
# 2                     100         7.9
# 3                      96         8.1
# 4                      99         8.2
# 5                      97         8.0
# 6                      75         7.2
# 7                      96         8.1
# 8                      95         8.4
# 9                      98         8.3
# 10                     98         8.3
# 11                     40         6.2
# 12                     79         7.1
# 13                     80         7.2
# 14                     98         8.1
# 15                     75         6.7
# 16                     94         7.2
# 17                     69         6.7
# 18                     97         8.4
# 19                     93         7.5
# 20                     97         7.6
# 21                     88         7.4
# 22                     95         8.0
# 23                     91         7.4
# ...

# %%
fig = px.scatter(df, x = df["rotten_tomatoes_score"], y = df["imdb_score"], width= 1200, height = 900)
fig.update_layout(xaxis = dict( title =  "rotten_tomatoes_score", showgrid = True)
                , yaxis = dict( title = "imdb_score", showgrid = True),
                    title = "Rotten tomatoes score vs IMDB score")
fig.show()

# %%
df1 = df[["rotten_tomatoes_score", "imdb_score", "film"]].sort_values(by = "rotten_tomatoes_score", ascending = False)

# %%
df1
# Out:
#     rotten_tomatoes_score  imdb_score                 film
# 0                     100         8.3            Toy Story
# 2                     100         7.9          Toy Story 2
# 4                      99         8.2         Finding Nemo
# 9                      98         8.3                   Up
# 10                     98         8.3          Toy Story 3
# 14                     98         8.1           Inside Out
# 5                      97         8.0      The Incredibles
# 18                     97         8.4                 Coco
# 20                     97         7.6          Toy Story 4
# 3                      96         8.1       Monsters, Inc.
# 7                      96         8.1          Ratatouille
# 22                     95         8.0                 Soul
# 8                      95         8.4               WALL-E
# 24                     95         7.0          Turning Red
# 16                     94         7.2         Finding Dory
# ...

# %%
df2 = df[["rotten_tomatoes_score", "imdb_score", "film"]].sort_values(by = "imdb_score", ascending = False)

# %%
df2
# Out:
#     rotten_tomatoes_score  imdb_score                 film
# 18                     97         8.4                 Coco
# 8                      95         8.4               WALL-E
# 0                     100         8.3            Toy Story
# 10                     98         8.3          Toy Story 3
# 9                      98         8.3                   Up
# 4                      99         8.2         Finding Nemo
# 7                      96         8.1          Ratatouille
# 14                     98         8.1           Inside Out
# 3                      96         8.1       Monsters, Inc.
# 5                      97         8.0      The Incredibles
# 22                     95         8.0                 Soul
# 2                     100         7.9          Toy Story 2
# 20                     97         7.6          Toy Story 4
# 27                     90         7.6         Inside Out 2
# 19                     93         7.5        Incredibles 2
# ...

# %%
fig = px.bar(df1, x = df1["film"], y = df1["rotten_tomatoes_score"], width= 1400, height = 900, color="rotten_tomatoes_score", color_continuous_scale="Blues")
fig.update_layout(xaxis_title =  "film", yaxis_title = "rotten_tomatoes_score", title = "Film scores in Rotten tomatoes")
fig.show()
# Out:
# <div>                            <div id="8cbd3d72-be67-426a-bfcf-69463e363914" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cbd3d72-be67-426a-bfcf-69463e363914")) {                    Plotly.newPlot(                        "8cbd3d72-be67-426a-bfcf-69463e363914",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003erotten_tomatoes_score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[100,100,99,98,98,98,97,97,97,96,96,95,95,95,94,93,92,91,90,88,80,79,75,75,74,73,69,40],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toy Story","Toy Story 2","Finding Nemo","Up","Toy Story 3"
# ...

# %%
fig = px.bar(df2, x = df2["film"], y = df2["imdb_score"], width= 1400, height = 900, color="imdb_score", color_continuous_scale="Blues")
fig.update_layout(xaxis_title =  "film", yaxis_title = "IMDB score", title = "Film scores in IMDB")
fig.show()
# Out:
# <div>                            <div id="fbaee647-1163-4131-8f92-8ed6b4e48a05" class="plotly-graph-div" style="height:900px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbaee647-1163-4131-8f92-8ed6b4e48a05")) {                    Plotly.newPlot(                        "fbaee647-1163-4131-8f92-8ed6b4e48a05",                        [{"alignmentgroup":"True","hovertemplate":"film=%{x}\u003cbr\u003eimdb_score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[8.4,8.4,8.3,8.3,8.3,8.2,8.1,8.1,8.1,8.0,8.0,7.9,7.6,7.6,7.5,7.4,7.4,7.2,7.2,7.2,7.2,7.1,7.0,7.0,6.7,6.7,6.2,6.1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Coco","WALL-E","Toy Story","Toy Story 3","U
# ...

# %% [markdown]
# ## Conclusions:
# - Both Toy Story and its sequel Toy Story 2 are the only pixar movies to generate 100 percent in rotten tomato scores, but they have different ratings in IMDB: Toy story has 8.3 IMDB Score while Toy story 2 has 7.9 IMDB Score.
# - Both Coco and Wall-E have the highest IMDB scores by 8.4 for each, but Coco has 97 percent in rotten tomato scores and Wall-E has 95 percent in rotten tomato scores.
# - Rotten tomatoes' scores reflect critic reviews while IMDB's scores reflect user reviews.

# %% [markdown]
# ## Q2: Compare critical reception vs. box office performance.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 2.3+ KB

# %%
df["Critical reception"] = df["rotten_tomatoes_score"] + df["imdb_score"] * 10 / 2

# %%
df[["Critical reception", "box_office_worldwide", "film"]]
# Out:
#     Critical reception  box_office_worldwide                 film
# 0                141.5             394436586            Toy Story
# 1                128.0             363258859         A Bug's Life
# 2                139.5             511358276          Toy Story 2
# 3                136.5             528773250       Monsters, Inc.
# 4                140.0             871014978         Finding Nemo
# 5                137.0             631442092      The Incredibles
# 6                111.0             461983149                 Cars
# 7                136.5             623726085          Ratatouille
# 8                137.0             521311860               WALL-E
# 9                139.5             735099082                   Up
# 10               139.5            1066969703          Toy Story 3
# 11                71.0             559852396               Cars 2
# 12               114.5             538983207                Brave
# ...

# %%
df3 = df[["Critical reception", "box_office_worldwide", "film"]].sort_values(by = "Critical reception", ascending = False)

# %%
df3
# Out:
#     Critical reception  box_office_worldwide                 film
# 0                141.5             394436586            Toy Story
# 4                140.0             871014978         Finding Nemo
# 9                139.5             735099082                   Up
# 2                139.5             511358276          Toy Story 2
# 10               139.5            1066969703          Toy Story 3
# 18               139.0             814641172                 Coco
# 14               138.5             857611174           Inside Out
# 8                137.0             521311860               WALL-E
# 5                137.0             631442092      The Incredibles
# 7                136.5             623726085          Ratatouille
# 3                136.5             528773250       Monsters, Inc.
# 22               135.0             121903885                 Soul
# 20               135.0            1073394593          Toy Story 4
# ...

# %%
fig = px.bar(df3, x = df3["film"], y = df3["Critical reception"], color = "box_office_worldwide", color_continuous_scale = "greens" ,  width = 1500, height = 1100)
fig.update_traces(textposition = "outside")
fig.update_layout(xaxis_title = "Film", yaxis_title = "Critical reception", title = "Box office performance vs Critical reception", xaxis_tickangle = -45)
fig.show()

# %% [markdown]
# ## Conclusions:
# - In critical reception terms:
# - - Toy Story has the highest critical reception next to it are:
#   - Finding Nemo, Up, Toy Story 2, Toy Story 3, Coco, Inside Out, Wall E, Incredibles, Ratatouille, Monsters Inc, Soul.
#   - Although these movies have the best critical receptions, they made the lowest revenues in comparison to
# - Inside out 2 which made the biggest revenues but low critical receptions in comparison to the previous Pixar movies.
# - Movies like The good Dinosaur, Elemental, Lightyear, Cars 3 and Cars 2 made the lowest revenues and have the lowest critical reception.

# %% [markdown]
# ## In Short:

# %% [markdown]
# - Pixar's greatest movies have one thing in common: timelesseness:
# - - Toy Story series (Friendship and Jealousy)
#   - Finding Nemo (Adulthood)
#   - Up (Moving on)
#   - Coco (Life and death)
#   - Incredibles (Nostalgia and family)
#   - Wall-E (Rebuilding civilization and human's dependence on technology)
#   - Rataouille (Ambition and dreams)
#   - Monsters Inc (Fear)
#   - Soul (Purpose of life)
#   - Inside out (emotions)
# - While Pixar's lowest rated movies are just great visuals with no soul.
# - Box office success and Critical reception don't align with each other as we have seen from this data.

# %% [markdown]
# ## Goal 3 : Release Date Trends:

# %% [markdown]
# ## Q1: Analyze which decades had the most successful releases.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
#  10  Critical reception          28 non-null     float64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 2.5+ KB

# %%
df[["film", "release_date"]]
# Out:
#                    film release_date
# 0             Toy Story    22-Nov-95
# 1          A Bug's Life    25-Nov-98
# 2           Toy Story 2    24-Nov-99
# 3        Monsters, Inc.     2-Nov-01
# 4          Finding Nemo    30-May-03
# 5       The Incredibles     5-Nov-04
# 6                  Cars     9-Jun-06
# 7           Ratatouille    29-Jun-07
# 8                WALL-E    27-Jun-08
# 9                    Up    29-May-09
# 10          Toy Story 3    18-Jun-10
# 11               Cars 2    24-Jun-11
# 12                Brave    22-Jun-12
# 13  Monsters University    21-Jun-13
# 14           Inside Out    19-Jun-15
# 15    The Good Dinosaur    25-Nov-15
# 16         Finding Dory    17-Jun-16
# 17               Cars 3    16-Jun-17
# 18                 Coco    22-Nov-17
# 19        Incredibles 2    15-Jun-18
# 20          Toy Story 4    21-Jun-19
# 21               Onward     6-Mar-20
# 22                 Soul    25-Dec-20
# 23                 Luca    18-Jun-21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     object
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
#  10  Critical reception          28 non-null     float64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 2.5+ KB

# %%
df["release_date"] = df["release_date"].astype("datetime64[ns]")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     datetime64[ns]
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
#  10  Critical reception          28 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(1)
# memory usage: 2.5+ KB

# %%
df["decade"] = (df["release_date"].dt.year // 10 * 10).astype(str) + "s"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          28 non-null     int64
#  1   film                        28 non-null     object
#  2   release_date                28 non-null     datetime64[ns]
#  3   budget                      28 non-null     int64
#  4   box_office_us_canada        28 non-null     int64
#  5   box_office_other            28 non-null     int64
#  6   box_office_worldwide        28 non-null     int64
#  7   rotten_tomatoes_score       28 non-null     int64
#  8   imdb_score                  28 non-null     float64
#  9   ROI (Return on Investment)  27 non-null     float64
#  10  Critical reception          28 non-null     float64
#  11  decade                      28 non-null     object
# dtypes: datetime64[ns](1), float64(3), int64(6), object(2)
# ...

# %%
df_decade = df.groupby("decade")["film"].count().reset_index()

# %%
df_decade
# Out:
#   decade  film
# 0  1990s     3
# 1  2000s     7
# 2  2010s    11
# 3  2020s     7

# %%
fig = px.bar(df_decade, x = df_decade["film"],  y = df_decade["decade"], 
             color = df.groupby("decade")["Critical reception"].mean(), 
             color_continuous_scale = "blues")
fig.update_layout(xaxis_title = "Number of films", yaxis_title = "Decade" ,title = "Most successful decade in Pixar")
fig.show()

# %% [markdown]
# ## Conclusions:
# - The 1990s and the 2000s are the most successful decades for Pixar:
# - - Hit after hit: Toy Story, Toy Story 2, A bug's life, Monsters inc, Incredibles and many more!
# - The 2010s is the start of the dark age for pixar:
# - - Although there were hits like Inside out, Toy story 3 and Coco.
#   - There were some flops like incredibles 2, The good dinosaur, Finding Dory, Cars 2 and Cars 3.
# - The 2020s is the decade where Pixar struggled, although there were a few hits like Soul and Inside out 2, there were several challenges:
# - - The launch of the Disney Plus platform.
#   - Theaters having weak receptions due to the pandemic.
#   - Weak receptions for Lightyear, Turning red and Elemnetal due to corporate decisions that Disney (the owner of Pixar) made.

# %% [markdown]
# ## Q2: Find the most profitable release month for Pixar movies

# %%
df["month"] = df["release_date"].dt.month_name()

# %%
df["month"].astype(str)
# Out:
# 0     November
# 1     November
# 2     November
# 3     November
# 4          May
# 5     November
# 6         June
# 7         June
# 8         June
# 9          May
# 10        June
# 11        June
# 12        June
# 13        June
# 14        June
# 15    November
# 16        June
# 17        June
# 18    November
# 19        June
# 20        June
# 21       March
# 22    December
# 23        June
# 24       March
# 25        June
# 26        June
# 27        June
# Name: month, dtype: object

# %%
df
# Out:
#     ID                 film release_date     budget  box_office_us_canada  \
# 0    1            Toy Story   1995-11-22   30000000             223225679
# 1    2         A Bug's Life   1998-11-25  120000000             162798565
# 2    3          Toy Story 2   1999-11-24   90000000             245852179
# 3    4       Monsters, Inc.   2001-11-02  115000000             255873250
# 4    5         Finding Nemo   2003-05-30   94000000             339714978
# 5    6      The Incredibles   2004-11-05   92000000             261441092
# 6    7                 Cars   2006-06-09  120000000             244082982
# 7    8          Ratatouille   2007-06-29  150000000             206445654
# 8    9               WALL-E   2008-06-27  180000000             223808164
# 9   10                   Up   2009-05-29  175000000             293004164
# 10  11          Toy Story 3   2010-06-18  200000000             415004880
# 11  12               Cars 2   2011-06-24  200000000             191452396
# ...

# %%
df_month = df.groupby("month")["Critical reception"].count().reset_index()

# %%
df_success = df_month.sort_values(by = "Critical reception", ascending = False)

# %%
df_success
# Out:
#       month  Critical reception
# 1      June                  16
# 4  November                   7
# 2     March                   2
# 3       May                   2
# 0  December                   1

# %%
fig = px.bar(df_success, x = df_success["month"], y = df_success["Critical reception"], 
             color = "Critical reception",
             color_continuous_scale = "blues")
fig.update_layout(title = "Most successful month for Pixar")
fig.show()

# %% [markdown]
# ## Conclusions:
# - June is the month with the most Pixar hits followed by November.
# - A lot of people go to movie theaters in Summer season and the christmas season.

# %% [markdown]
# ## Goal 4: Franchise Success
# ## Compare Toy Story films vs. other Pixar franchises.

# %%
df["Franchise"] = df["film"].apply(lambda x: "Toy Story" if "Toy Story" in x else "Other Pixar")

# %%
df
# Out:
#     ID                 film release_date     budget  box_office_us_canada  \
# 0    1            Toy Story   1995-11-22   30000000             223225679
# 1    2         A Bug's Life   1998-11-25  120000000             162798565
# 2    3          Toy Story 2   1999-11-24   90000000             245852179
# 3    4       Monsters, Inc.   2001-11-02  115000000             255873250
# 4    5         Finding Nemo   2003-05-30   94000000             339714978
# 5    6      The Incredibles   2004-11-05   92000000             261441092
# 6    7                 Cars   2006-06-09  120000000             244082982
# 7    8          Ratatouille   2007-06-29  150000000             206445654
# 8    9               WALL-E   2008-06-27  180000000             223808164
# 9   10                   Up   2009-05-29  175000000             293004164
# 10  11          Toy Story 3   2010-06-18  200000000             415004880
# 11  12               Cars 2   2011-06-24  200000000             191452396
# ...

# %%
df_Franchise = df.groupby("Franchise")["film"].count().reset_index()

# %%
df_Franchise
# Out:
#      Franchise  film
# 0  Other Pixar    24
# 1    Toy Story     4

# %%
fig = px.bar(df_Franchise, x =  df_Franchise["Franchise"], y =  df_Franchise["film"]  , color = df.groupby("Franchise")["Critical reception"].mean() ,  
             color_continuous_scale = "blues")
fig.update_layout(xaxis_title = "Franchise", yaxis_title = "Number of films")
fig.show()

# %% [markdown]
# ## Conclusions:
# - Although the toy story franchise has about 4 films which is lower than Pixar's massive catalogue, it's still the most successful Pixar franchise until now.
# - Pixar focuses on making standalone movies rather than franchise movies like Dreamworks (Kung fu Panda, Shrek, How to train you dragon), Disney (Lion king, Mulan, Wreck it ralph) and Sony (Spiderverse and Cloudy).

# %% [markdown]
# ## Analyze if sequels tend to perform better or worse than original movies.

# %%
df["Sequel or original"] = df["film"].apply(lambda x: "Sequel" if any(n in x for n in ["2", "3", "4"])  else "Original")

# %%
df
# Out:
#     ID                 film release_date     budget  box_office_us_canada  \
# 0    1            Toy Story   1995-11-22   30000000             223225679
# 1    2         A Bug's Life   1998-11-25  120000000             162798565
# 2    3          Toy Story 2   1999-11-24   90000000             245852179
# 3    4       Monsters, Inc.   2001-11-02  115000000             255873250
# 4    5         Finding Nemo   2003-05-30   94000000             339714978
# 5    6      The Incredibles   2004-11-05   92000000             261441092
# 6    7                 Cars   2006-06-09  120000000             244082982
# 7    8          Ratatouille   2007-06-29  150000000             206445654
# 8    9               WALL-E   2008-06-27  180000000             223808164
# 9   10                   Up   2009-05-29  175000000             293004164
# 10  11          Toy Story 3   2010-06-18  200000000             415004880
# 11  12               Cars 2   2011-06-24  200000000             191452396
# ...

# %%
fig = px.bar(df, x = df["film"], y = df["Critical reception"], 
             color = df["Sequel or original"],
             color_discrete_map ={"Original": "green", "Sequel": "Purple"}, 
             width = 1200, height = 900)
fig.update_layout(xaxis_title = "film", yaxis_title = "Critical reception", title = "Originals and sequels success rate", 
                  xaxis = dict(tickangle = -35))
fig.show()

# %% [markdown]
# ## Conclusions:

# %% [markdown]
# - A lot of Pixar's most successful movies are original movies with the exception of Cars, Brave, the good dinosaur and Elemental.
# - Some Pixar sequels are hits like:
# - - The toy story sequels
# - - Incredibles 2
# - - Inside out 2
# - Cars is the least popular Pixar franchise in terms of critical reception.
